# %% [markdown]
# # TLDR;
#
# ## Playing around with GraphViz to make it present groups in a particular order
# ## Playing around with NetworkX - has:
# ### a bunch of abstract graph algorithms
# ### and some graph drawing capabilities as well

# %% [markdown]
# # Start with a List of Table Dependencies
#
# ## Each paragraph is a table followed by other tables that feed into it.
#
# ### E.G/ words, table 1 depends on tables 2, 3, 4, and 5 in the first chunk
# ```
# team.table_1
# play.table_2
# reporting.table_3
# public.table_4
# reporting.table_5
# ```

# %%
tables = """

team.table_1
play.table_2
reporting.table_3
public.table_4
reporting.table_5


team.table_6
play.table_2
reporting.table_3
public.table_4
reporting.table_5


team.table_7
team.table_8
team.table_9
team.table_10
team.table_11

team.table_12
other.table_13


team.table_11
team.table_12


team.table_10
other.table_13


team.table_14
play.table_2
public.table_4
team.table_7

team.table_15
play.table_2
public.table_4


team.table_16
team.table_15
other.table_13

team.table_17
team.table_1
team.table_16


team.table_18
team.table_15
other.table_13

team.table_19
team.table_15
team.table_18


team.table_20
team.table_18
team.table_19


team.table_21
team.table_20
team.table_19

team.table_22
team.table_1
reporting.table_23
public.table_24

team.table_25
play.table_26
public.table_4


team.table_27
team.table_25
public.table_24


team.table_28
public.table_29


team.table_30
team.table_31
team.table_6
reporting.table_32


team.table_33
play.table_2
team.table_6
team.table_28
team.table_1
reporting.table_5
team.table_30


team.table_31
public.table_29
public.table_34
team.table_30

team.table_35
team.table_22
team.table_33


team.table_36
play.table_26
team.table_27
team.table_37


team.table_38
team.table_36


team.table_39
play.table_26
reporting.table_5
team.table_40
public.table_41
public.table_42
public.table_43
public.table_44


team.table_45
play.table_2
public.table_4
public.table_41


team.table_46
play.table_26
public.table_4


team.table_47
play.table_2
team.table_39
team.table_45
team.table_46


team.table_48
team.table_38
team.table_47


team.table_49
other.table_50


team.table_51
play.table_26
reporting.table_5
team.table_49


team.table_52
play.table_2
reporting.table_5
reporting.table_3


team.table_53
team.table_52


team.table_54
team.table_40
reporting.table_5
public.table_42
public.table_43
public.table_44
public.table_24


team.table_55
team.table_54


team.table_56
play.table_2
team.table_14
team.table_17
team.table_33
team.table_35
team.table_38
team.table_47
team.table_48
team.table_51
team.table_53
team.table_55


team.table_57
play.table_2
team.table_14
team.table_17
team.table_21
team.table_33
team.table_35
team.table_38
team.table_47
team.table_48
team.table_51
team.table_53
team.table_55
"""

# %%
# Something I used to obfuscate with
#
# lines = [line for line in tables.split("\n")]

# schema_renamer = {
#     'lms_public': 'public',
#     'lms_reporting': 'reporting',
#     'keyvals': 'other',
# }

# for line in lines:
#     parts = line.split(".")

#     if len(parts) == 1:
#         print(line)
#     else:
#         if parts[0] in schema_renamer:
#             parts[0] = schema_renamer[parts[0]]
#         parts[1] = f'table_{labels[line]}'
#         print(".".join(parts))

# %% [markdown]
# # Build the Graph

# %%
def build_graph(tables_str):
    graph = {}

    is_source = True
    for line in tables_str.split("\n"):
        token = line.strip()
        if len(token) == 0:
            is_source = True
        else:
            if is_source:
                source = token
                if source in graph:
                    print(f"UH OHH. OVERWRITING {source} -> {graph[source]}")
                graph[source] = []
                is_source = False
            else:
                graph[source].append(token)
                
    return graph

# %%
import json


graph = build_graph(tables)
print(json.dumps(graph, indent=4))
# Out:
# {
#     "team.table_1": [
#         "play.table_2",
#         "reporting.table_3",
#         "public.table_4",
#         "reporting.table_5"
#     ],
#     "team.table_6": [
#         "play.table_2",
#         "reporting.table_3",
#         "public.table_4",
#         "reporting.table_5"
#     ],
#     "team.table_7": [
#         "team.table_8",
#         "team.table_9",
#         "team.table_10",
#         "team.table_11"
#     ],
#     "team.table_12": [
#         "other.table_13"
#     ],
#     "team.table_11": [
#         "team.table_12"
#     ],
#     "team.table_10": [
#         "other.table_13"
#     ],
#     "team.table_14": [
#         "play.table_2",
#         "public.table_4",
#         "team.table_7"
#     ],
#     "team.table_15": [
#         "play.table_2",
#         "public.table_4"
#     ],
#     "team.table_16": [
#         "team.table_15",
#         "other.table_13"
#     ],
#     "team.table_17": [
#         "team.table_1",
#         "team.table_16"
#     ],
#     "team.table_18": [
#         "team.table_15",
#         "other.table_13"
#     ],
#     "team.table_19": [
#         "team.table_15",
#         "team.table_18"
#     ],
#     "team.table_20": [
#         "team.table_18",
#         "team.table_19"
#     ],
#     "team.table_21": [
#         "team.table_20",
#         "team.table_19"
#     ],
#     "team.table_22": [
#         "team.table_1",
#         "reporting.table_23",
#         "public.table_24"
#     ],
#     "team.table_25": [
#         "play.table_26",
#         "public.table_4"
#     ],
#     "team.table_27": [
#         "team.table_25",
#         "public.table_24"
#     ],
#     "team.table_28": [
#         "public.table_29"
#     ],
#     "team.table_30": [
#         "team.table_31",
#         "team.table_6",
#         "reporting.table_32"
#     ],
#     "team.table_33": [
#         "play.table_2",
#         "team.table_6",
#         "team.table_28",
#         "team.table_1",
#         "reporting.table_5",
#         "team.table_30"
#     ],
#     "team.table_31": [
#         "public.table_29",
#         "public.table_34",
#         "team.table_30"
#     ],
#     "team.table_35": [
#         "team.table_22",
#         "team.table_33"
#     ],
#     "team.table_36": [
#         "play.table_26",
#         "team.table_27",
#         "team.table_37"
#     ],
#     "team.table_38": [
#         "team.table_36"
#     ],
#     "team.table_39": [
#         "play.table_26",
#         "reporting.table_5",
#         "team.table_40",
#         "public.table_41",
#         "public.table_42",
#         "public.table_43",
#         "public.table_44"
#     ],
#     "team.table_45": [
#         "play.table_2",
#         "public.table_4",
#         "public.table_41"
#     ],
#     "team.table_46": [
#         "play.table_26",
#         "public.table_4"
#     ],
#     "team.table_47": [
#         "play.table_2",
#         "team.table_39",
#         "team.table_45",
#         "team.table_46"
#     ],
#     "team.table_48": [
#         "team.table_38",
#         "team.table_47"
#     ],
#     "team.table_49": [
#         "other.table_50"
#     ],
#     "team.table_51": [
#         "play.table_26",
#         "reporting.table_5",
#         "team.table_49"
#     ],
#     "team.table_52": [
#         "play.table_2",
#         "reporting.table_5",
#         "reporting.table_3"
#     ],
#     "team.table_53": [
#         "team.table_52"
#     ],
#     "team.table_54": [
#         "team.table_40",
#         "reporting.table_5",
#         "public.table_42",
#         "public.table_43",
#         "public.table_44",
#         "public.table_24"
#     ],
#     "team.table_55": [
#         "team.table_54"
#     ],
#     "team.table_56": [
#         "play.table_2",
#         "team.table_14",
#         "team.table_17",
#         "team.table_33",
#         "team.table_35",
#         "team.table_38",
#         "team.table_47",
#         "team.table_48",
#         "team.table_51",
#         "team.table_53",
#         "team.table_55"
#     ],
#     "team.table_57": [
#         "play.table_2",
#         "team.table_14",
#         "team.table_17",
#         "team.table_21",
#         "team.table_33",
#         "team.table_35",
#         "team.table_38",
#         "team.table_47",
#         "team.table_48",
#         "team.table_51",
#         "team.table_53",
#         "team.table_55"
#     ]
# }

# %% [markdown]
# ## Labels, in case need to have numbers instead of names to save space

# %%
def get_labels_edges(graph_dict):
    i = 1
    labels = {}
    edges = []
    for target, sources in graph_dict.items():
        if target not in labels:
            labels[target] = i
            i += 1
        for source in sources:
            if source not in labels:
                labels[source] = i
                i += 1
            edges.append((labels[source], labels[target]))

    reverse = {v:k for k,v in labels.items()}
    return labels, reverse, edges

# %%
labels, reverse, edges = get_labels_edges(graph)

reverse
# Out:
# {1: 'team.table_1',
#  2: 'play.table_2',
#  3: 'reporting.table_3',
#  4: 'public.table_4',
#  5: 'reporting.table_5',
#  6: 'team.table_6',
#  7: 'team.table_7',
#  8: 'team.table_8',
#  9: 'team.table_9',
#  10: 'team.table_10',
#  11: 'team.table_11',
#  12: 'team.table_12',
#  13: 'other.table_13',
#  14: 'team.table_14',
#  15: 'team.table_15',
#  16: 'team.table_16',
#  17: 'team.table_17',
#  18: 'team.table_18',
#  19: 'team.table_19',
#  20: 'team.table_20',
#  21: 'team.table_21',
#  22: 'team.table_22',
#  23: 'reporting.table_23',
#  24: 'public.table_24',
#  25: 'team.table_25',
#  26: 'play.table_26',
#  27: 'team.table_27',
#  28: 'team.table_28',
#  29: 'public.table_29',
#  30: 'team.table_30',
#  31: 'team.table_31',
#  32: 'reporting.table_32',
#  33: 'team.table_33',
#  34: 'public.table_34',
#  35: 'team.table_35',
#  36: 'team.table_36',
#  37: 'team.table_37',
#  38: 'team.table_38',
#  39: 'team.table_39',
#  40: 'team.table_40',
#  41: 'public.table_41',
#  42: 'public.table_42',
#  43: 'public.table_43',
#  44: 'public.table_44',
#  45: 'team.table_45',
#  46: 'team.table_46',
#  47: 'team.table_47',
#  48: 'team.table_48',
#  49: 'team.table_49',
#  50: 'other.table_50',
#  51: 'team.table_51',
#  52: 'team.table_52',
#  53: 'team.table_53',
#  54: 'team.table_54',
#  55: 'team.table_55',
#  56: 'team.table_56',
#  57: 'team.table_57'}

# %% [markdown]
# ## Shells (aka "rank") - based on appearance in SQL Query

# %%
def get_naive_groupings(graph_dict):
    shells = []
    shell_next = []
    already_seen = set()
    for target, sources in graph_dict.items():
        shell_curr = shell_next
        for source in sources:
            s = labels[source]
            if not s in already_seen:
                shell_curr.append(s)
            already_seen.add(s)

        if len(shell_curr) > 0:
            shells.append(shell_curr)

        shell_next = []
        t = labels[target]
        if not t in already_seen:
            shell_next.append(t)
        already_seen.add(t)

    if len(shell_next) > 0:
        shells.append(shell_next)

    return shells

# %%
shells = get_naive_groupings(graph)

shells
# Out:
# [[2, 3, 4, 5],
#  [1],
#  [6, 8, 9, 10, 11],
#  [7, 13],
#  [12],
#  [14],
#  [15],
#  [16],
#  [17],
#  [18],
#  [19],
#  [20],
#  [21, 23, 24],
#  [22, 26],
#  [25],
#  [27, 29],
#  [28, 31, 32],
#  [30],
#  [33, 34],
#  [35, 37],
#  [36],
#  [38, 40, 41, 42, 43, 44],
#  [39],
#  [45],
#  [46],
#  [47],
#  [48, 50],
#  [49],
#  [51],
#  [52],
#  [53],
#  [54],
#  [55],
#  [56],
#  [57]]

# %% [markdown]
# ## DB Schemas - with colors

# %%
schemas = set()
for v in reverse.values():
    schemas.add(v.split(".")[0])
    
schemas
# Out:
# {'other', 'play', 'public', 'reporting', 'team'}

# %% [markdown]
# ### Define Colors based on Schema

# %%
schema_colors = {
 'play': 'red',
 'team': 'yellow',
 'other': 'green',
 'public': 'grey',
 'reporting': 'blue',
}
def get_color(node_number):
    return schema_colors[reverse[node_number].split(".")[0]]

# %% [markdown]
# # Legend

# %%
reverse
# Out:
# {1: 'team.table_1',
#  2: 'play.table_2',
#  3: 'reporting.table_3',
#  4: 'public.table_4',
#  5: 'reporting.table_5',
#  6: 'team.table_6',
#  7: 'team.table_7',
#  8: 'team.table_8',
#  9: 'team.table_9',
#  10: 'team.table_10',
#  11: 'team.table_11',
#  12: 'team.table_12',
#  13: 'other.table_13',
#  14: 'team.table_14',
#  15: 'team.table_15',
#  16: 'team.table_16',
#  17: 'team.table_17',
#  18: 'team.table_18',
#  19: 'team.table_19',
#  20: 'team.table_20',
#  21: 'team.table_21',
#  22: 'team.table_22',
#  23: 'reporting.table_23',
#  24: 'public.table_24',
#  25: 'team.table_25',
#  26: 'play.table_26',
#  27: 'team.table_27',
#  28: 'team.table_28',
#  29: 'public.table_29',
#  30: 'team.table_30',
#  31: 'team.table_31',
#  32: 'reporting.table_32',
#  33: 'team.table_33',
#  34: 'public.table_34',
#  35: 'team.table_35',
#  36: 'team.table_36',
#  37: 'team.table_37',
#  38: 'team.table_38',
#  39: 'team.table_39',
#  40: 'team.table_40',
#  41: 'public.table_41',
#  42: 'public.table_42',
#  43: 'public.table_43',
#  44: 'public.table_44',
#  45: 'team.table_45',
#  46: 'team.table_46',
#  47: 'team.table_47',
#  48: 'team.table_48',
#  49: 'team.table_49',
#  50: 'other.table_50',
#  51: 'team.table_51',
#  52: 'team.table_52',
#  53: 'team.table_53',
#  54: 'team.table_54',
#  55: 'team.table_55',
#  56: 'team.table_56',
#  57: 'team.table_57'}

# %% [markdown]
# # GraphViz Stab 1: Modest Success

# %%
from graphviz import Digraph

# %%
def public_attributes(obj):
    return {name: obj.__getattribute__(name) for name in dir(obj) if not name.startswith('_')}

# public_attributes(ecm_dependency_graph)

# %% [markdown]
# #### Resized graph thanks to [this StackOverflow](https://stackoverflow.com/questions/3428448/reducing-the-size-as-in-area-of-the-graph-generated-by-graphviz)

# %%
def dependency_graph(graph_dict, reverse_dict, rank_groups, 
                     label_with_tables=False, 
                     scaler=1, 
                     fixed_size=False,
                     with_node_constraints=True,
                     top_to_bottom=True,
                     escalating_ranks=False,
                    ):
    
    graph_attributes = {
        'nodesep': f'{0.05 * scaler}',
        'ranksep': '0.75', #f'{0.05 * scaler}',
        'rankdir': 'TB' if top_to_bottom else 'LR',
    }
    if fixed_size:
        graph_attributes['size'] = "20,8" if label_with_tables else "8,11"

    edge_attribute = {
        'weight': f'{1.2 * scaler}',
    }

    node_attributes = {
        'fontsize': '11',
        'shape': 'box' if label_with_tables else 'circle',
    }

    ecm_dependency_graph = Digraph("ECM Table Dependency", 
                                   graph_attr=graph_attributes,
                                   edge_attr=edge_attribute,
                                   node_attr=node_attributes,
                              )

    for target, sources in graph_dict.items():
        for source in sources:
            ecm_dependency_graph.edge(source, target, constraint=('true' if with_node_constraints else 'false'))

    for level, group in enumerate(rank_groups):        
        with ecm_dependency_graph.subgraph(name=f'group_{level}') as sg:
            rank = 'same' + (f'_{level:>08d}' if escalating_ranks else '')
            sg.graph_attr.update(rank=rank)
            for node in group:
                label = None if label_with_tables else str(node)
                sg.node(reverse_dict[node], style='filled', color=get_color(node), label=label)


    return ecm_dependency_graph

# %%
dependency_graph(graph, reverse, shells, fixed_size=True, scaler=1.5, escalating_ranks=False, top_to_bottom=False)

# %%
dependency_graph(graph, reverse, shells, True, fixed_size=True, scaler=1.5, top_to_bottom=True)

# %% [markdown]
# # NetworkX - useful for topologically sorting and other graph algos

# %%
import networkx as nx 
G = nx.DiGraph() 
G.add_edges_from(edges)

# %%
# G.is_directed_acyclic_graph()
nx.is_directed_acyclic_graph(G)
# Out:
# False

# %%
nx.find_cycle(G)
# Out:
# [(30, 31), (31, 30)]

# %% [markdown]
# ## Damn, that means we can't do a topological sort

# %%
list(nx.topological_sort(G))
# Out:
# ---------------------------------------------------------------------------
# NetworkXUnfeasible                        Traceback (most recent call last)
# <ipython-input-59-e3ae21fff338> in <module>
# ----> 1 list(nx.topological_sort(G))
#
# /opt/conda/lib/python3.7/site-packages/networkx/algorithms/dag.py in topological_sort(G)
#     208
#     209     if indegree_map:
# --> 210         raise nx.NetworkXUnfeasible("Graph contains a cycle or graph changed "
#     211                                     "during iteration")
#     212
#
# NetworkXUnfeasible: Graph contains a cycle or graph changed during iteration

# %% [markdown]
# ### So let's break that cycle

# %%
relevant = {k:graph[k] for k in [reverse[30], reverse[31]]}
relevant
# Out:
# {'team.table_30': ['team.table_31', 'team.table_6', 'reporting.table_32'],
#  'team.table_31': ['public.table_29', 'public.table_34', 'team.table_30']}

# %% [markdown]
# #### Looking at the SQL... (not included)
# ...remove element in the graph `'team.table_31': ['team.table_30']`

# %%
del graph[reverse[31]][2]

# %% [markdown]
# ## Rebuild the graph and ancillary data

# %%
labels, reverse, edges = get_labels_edges(graph)

G = nx.DiGraph() 
G.add_edges_from(edges)

# %%
nx.is_directed_acyclic_graph(G)
# Out:
# True

# %%
top_sorted = list(nx.topological_sort(G))
top_sorted
# Out:
# [50,
#  49,
#  44,
#  43,
#  42,
#  41,
#  40,
#  37,
#  34,
#  32,
#  29,
#  31,
#  28,
#  26,
#  24,
#  23,
#  13,
#  10,
#  12,
#  11,
#  9,
#  8,
#  7,
#  5,
#  54,
#  55,
#  51,
#  39,
#  4,
#  46,
#  25,
#  27,
#  36,
#  38,
#  3,
#  2,
#  52,
#  53,
#  45,
#  47,
#  48,
#  15,
#  18,
#  19,
#  20,
#  21,
#  16,
#  14,
#  6,
#  30,
#  1,
#  33,
#  22,
#  35,
#  17,
#  57,
#  56]

# %%
def ranked_topological_sort(nx_graph):
    """
    returns a list of lists representing a grouping of a topological sorting into equivalent
    orderings
    
    NOT VERY EFFICIENT
    """
    top_groupings = []
    g = nx_graph.copy()
    while len(g) > 0:
        sources = get_all_sources(g)
        top_groupings.append(sources)
        g.remove_nodes_from(sources)
        
    return top_groupings

def get_all_sources(nx_graph):
    return [n for n in nx_graph if nx_graph.in_degree(n) == 0]

# %%
len(G)
# Out:
# 57

# %%
G.in_degree(47)
# Out:
# 4

# %%
get_all_sources(G)
# Out:
# [2, 3, 4, 5, 8, 9, 13, 23, 24, 26, 29, 32, 34, 37, 40, 41, 42, 43, 44, 50]

# %%
topo_ranks = ranked_topological_sort(G)

topo_ranks
# Out:
# [[2, 3, 4, 5, 8, 9, 13, 23, 24, 26, 29, 32, 34, 37, 40, 41, 42, 43, 44, 50],
#  [1, 6, 10, 12, 15, 25, 28, 31, 39, 45, 46, 49, 52, 54],
#  [11, 16, 18, 22, 27, 30, 47, 51, 53, 55],
#  [7, 17, 19, 33, 36],
#  [14, 20, 35, 38],
#  [21, 48],
#  [56, 57]]

# %% [markdown]
# ## Break the first group by color
#
# * red, yellow, green, grey, blue

# %%
first_groups = {}
for source in topo_ranks[0]:
    color = get_color(source)

    if color not in first_groups:
        first_groups[color] = []
    first_groups[color].append(source)

first_groups

rankings = []
rankings.append(first_groups['red'])
rankings.append(first_groups['yellow'])
rankings.append(first_groups['green'])
rankings.append(first_groups['grey'])
rankings.append(first_groups['blue'])
rankings.reverse()
for i in range(1, len(topo_ranks)):
    rankings.append(topo_ranks[i])
    
# list(reversed(rankings)), rankings

# %%
dg = dependency_graph(graph, reverse, rankings, 
                      fixed_size=True, 
                      scaler=4, 
                      with_node_constraints=True,
                      escalating_ranks=True,
                      top_to_bottom=False,
                     )

print(dg.source)
dg
# Out:
# digraph "ECM Table Dependency" {
# 	graph [nodesep=0.2 rankdir=LR ranksep=0.75 size="8,11"]
# 	node [fontsize=11 shape=circle]
# 	edge [weight=4.8]
# 	"play.table_2" -> "team.table_1" [constraint=true]
# 	"reporting.table_3" -> "team.table_1" [constraint=true]
# 	"public.table_4" -> "team.table_1" [constraint=true]
# 	"reporting.table_5" -> "team.table_1" [constraint=true]
# 	"play.table_2" -> "team.table_6" [constraint=true]
# 	"reporting.table_3" -> "team.table_6" [constraint=true]
# 	"public.table_4" -> "team.table_6" [constraint=true]
# 	"reporting.table_5" -> "team.table_6" [constraint=true]
# 	"team.table_8" -> "team.table_7" [constraint=true]
# 	"team.table_9" -> "team.table_7" [constraint=true]
# 	"team.table_10" -> "team.table_7" [constraint=true]
# 	"team.table_11" -> "team.table_7" [constraint=true]
# 	"other.table_13" -> "team.table_12" [constraint=true]
# 	"team.table_12" -> "team.table_11" [constraint=true]
# 	"other.table_13" -> "team.table_10" [constraint=true]
# 	"play.table_2" -> "team.table_14" [constraint=true]
# 	"public.table_4" -> "team.table_14" [constraint=true]
# 	"team.table_7" -> "team.table_14" [constraint=true]
# 	"play.table_2" -> "team.table_15" [constraint=true]
# 	"public.table_4" -> "team.table_15" [constraint=true]
# 	"team.table_15" -> "team.table_16" [constraint=true]
# 	"other.table_13" -> "team.table_16" [constraint=true]
# 	"team.table_1" -> "team.table_17" [constraint=true]
# 	"team.table_16" -> "team.table_17" [constraint=true]
# 	"team.table_15" -> "team.table_18" [constraint=true]
# 	"other.table_13" -> "team.table_18" [constraint=true]
# 	"team.table_15" -> "team.table_19" [constraint=true]
# 	"team.table_18" -> "team.table_19" [constraint=true]
# 	"team.table_18" -> "team.table_20" [constraint=true]
# 	"team.table_19" -> "team.table_20" [constraint=true]
# 	"team.table_20" -> "team.table_21" [constraint=true]
# 	"team.table_19" -> "team.table_21" [constraint=true]
# 	"team.table_1" -> "team.table_22" [constraint=true]
# 	"reporting.table_23" -> "team.table_22" [constraint=true]
# 	"public.table_24" -> "team.table_22" [constraint=true]
# 	"play.table_26" -> "team.table_25" [constraint=true]
# 	"public.table_4" -> "team.table_25" [constraint=true]
# 	"team.table_25" -> "team.table_27" [constraint=true]
# 	"public.table_24" -> "team.table_27" [constraint=true]
# 	"public.table_29" -> "team.table_28" [constraint=true]
# 	"team.table_31" -> "team.table_30" [constraint=true]
# 	"team.table_6" -> "team.table_30" [constraint=true]
# 	"reporting.table_32" -> "team.table_30" [constraint=true]
# 	"play.table_2" -> "team.table_33" [constraint=true]
# 	"team.table_6" -> "team.table_33" [constraint=true]
# 	"team.table_28" -> "team.table_33" [constraint=true]
# 	"team.table_1" -> "team.table_33" [constraint=true]
# 	"reporting.table_5" -> "team.table_33" [constraint=true]
# 	"team.table_30" -> "team.table_33" [constraint=true]
# 	"public.table_29" -> "team.table_31" [constraint=true]
# 	"public.table_34" -> "team.table_31" [constraint=true]
# 	"team.table_22" -> "team.table_35" [constraint=true]
# 	"team.table_33" -> "team.table_35" [constraint=true]
# 	"play.table_26" -> "team.table_36" [constraint=true]
# 	"team.table_27" -> "team.table_36" [constraint=true]
# 	"team.table_37" -> "team.table_36" [constraint=true]
# 	"team.table_36" -> "team.table_38" [constraint=true]
# 	"play.table_26" -> "team.table_39" [constraint=true]
# 	"reporting.table_5" -> "team.table_39" [constraint=true]
# 	"team.table_40" -> "team.table_39" [constraint=true]
# 	"public.table_41" -> "team.table_39" [constraint=true]
# 	"public.table_42" -> "team.table_39" [constraint=true]
# 	"public.table_43" -> "team.table_39" [constraint=true]
# 	"public.table_44" -> "team.table_39" [constraint=true]
# 	"play.table_2" -> "team.table_45" [constraint=true]
# 	"public.table_4" -> "team.table_45" [constraint=true]
# 	"public.table_41" -> "team.table_45" [constraint=true]
# 	"play.table_26" -> "team.table_46" [constraint=true]
# 	"public.table_4" -> "team.table_46" [constraint=true]
# 	"play.table_2" -> "team.table_47" [constraint=true]
# 	"team.table_39" -> "team.table_47" [constraint=true]
# 	"team.table_45" -> "team.table_47" [constraint=true]
# 	"team.table_46" -> "team.table_47" [constraint=true]
# 	"team.table_38" -> "team.table_48" [constraint=true]
# 	"team.table_47" -> "team.table_48" [constraint=true]
# 	"other.table_50" -> "team.table_49" [constraint=true]
# 	"play.table_26" -> "team.table_51" [constraint=true]
# 	"reporting.table_5" -> "team.table_51" [constraint=true]
# 	"team.table_49" -> "team.table_51" [constraint=true]
# 	"play.table_2" -> "team.table_52" [constraint=true]
# 	"reporting.table_5" -> "team.table_52" [constraint=true]
# 	"reporting.table_3" -> "team.table_52" [constraint=true]
# 	"team.table_52" -> "team.table_53" [constraint=true]
# 	"team.table_40" -> "team.table_54" [constraint=true]
# 	"reporting.table_5" -> "team.table_54" [constraint=true]
# 	"public.table_42" -> "team.table_54" [constraint=true]
# 	"public.table_43" -> "team.table_54" [constraint=true]
# 	"public.table_44" -> "team.table_54" [constraint=true]
# 	"public.table_24" -> "team.table_54" [constraint=true]
# 	"team.table_54" -> "team.table_55" [constraint=true]
# 	"play.table_2" -> "team.table_56" [constraint=true]
# 	"team.table_14" -> "team.table_56" [constraint=true]
# 	"team.table_17" -> "team.table_56" [constraint=true]
# 	"team.table_33" -> "team.table_56" [constraint=true]
# 	"team.table_35" -> "team.table_56" [constraint=true]
# 	"team.table_38" -> "team.table_56" [constraint=true]
# 	"team.table_47" -> "team.table_56" [constraint=true]
# 	"team.table_48" -> "team.table_56" [constraint=true]
# 	"team.table_51" -> "team.table_56" [constraint=true]
# 	"team.table_53" -> "team.table_56" [constraint=true]
# 	"team.table_55" -> "team.table_56" [constraint=true]
# 	"play.table_2" -> "team.table_57" [constraint=true]
# 	"team.table_14" -> "team.table_57" [constraint=true]
# 	"team.table_17" -> "team.table_57" [constraint=true]
# 	"team.table_21" -> "team.table_57" [constraint=true]
# 	"team.table_33" -> "team.table_57" [constraint=true]
# 	"team.table_35" -> "team.table_57" [constraint=true]
# 	"team.table_38" -> "team.table_57" [constraint=true]
# 	"team.table_47" -> "team.table_57" [constraint=true]
# 	"team.table_48" -> "team.table_57" [constraint=true]
# 	"team.table_51" -> "team.table_57" [constraint=true]
# 	"team.table_53" -> "team.table_57" [constraint=true]
# 	"team.table_55" -> "team.table_57" [constraint=true]
# 	subgraph group_0 {
# 		graph [rank=same_00000000]
# 		"reporting.table_3" [label=3 color=blue style=filled]
# 		"reporting.table_5" [label=5 color=blue style=filled]
# 		"reporting.table_23" [label=23 color=blue style=filled]
# 		"reporting.table_32" [label=32 color=blue style=filled]
# 	}
# 	subgraph group_1 {
# 		graph [rank=same_00000001]
# 		"public.table_4" [label=4 color=grey style=filled]
# 		"public.table_24" [label=24 color=grey style=filled]
# 		"public.table_29" [label=29 color=grey style=filled]
# 		"public.table_34" [label=34 color=grey style=filled]
# 		"public.table_41" [label=41 color=grey style=filled]
# 		"public.table_42" [label=42 color=grey style=filled]
# 		"public.table_43" [label=43 color=grey style=filled]
# 		"public.table_44" [label=44 color=grey style=filled]
# 	}
# 	subgraph group_2 {
# 		graph [rank=same_00000002]
# 		"other.table_13" [label=13 color=green style=filled]
# 		"other.table_50" [label=50 color=green style=filled]
# 	}
# 	subgraph group_3 {
# 		graph [rank=same_00000003]
# 		"team.table_8" [label=8 color=yellow style=filled]
# 		"team.table_9" [label=9 color=yellow style=filled]
# 		"team.table_37" [label=37 color=yellow style=filled]
# 		"team.table_40" [label=40 color=yellow style=filled]
# 	}
# 	subgraph group_4 {
# 		graph [rank=same_00000004]
# 		"play.table_2" [label=2 color=red style=filled]
# 		"play.table_26" [label=26 color=red style=filled]
# 	}
# 	subgraph group_5 {
# 		graph [rank=same_00000005]
# 		"team.table_1" [label=1 color=yellow style=filled]
# 		"team.table_6" [label=6 color=yellow style=filled]
# 		"team.table_10" [label=10 color=yellow style=filled]
# 		"team.table_12" [label=12 color=yellow style=filled]
# 		"team.table_15" [label=15 color=yellow style=filled]
# 		"team.table_25" [label=25 color=yellow style=filled]
# 		"team.table_28" [label=28 color=yellow style=filled]
# 		"team.table_31" [label=31 color=yellow style=filled]
# 		"team.table_39" [label=39 color=yellow style=filled]
# 		"team.table_45" [label=45 color=yellow style=filled]
# 		"team.table_46" [label=46 color=yellow style=filled]
# 		"team.table_49" [label=49 color=yellow style=filled]
# 		"team.table_52" [label=52 color=yellow style=filled]
# 		"team.table_54" [label=54 color=yellow style=filled]
# 	}
# 	subgraph group_6 {
# 		graph [rank=same_00000006]
# 		"team.table_11" [label=11 color=yellow style=filled]
# 		"team.table_16" [label=16 color=yellow style=filled]
# 		"team.table_18" [label=18 color=yellow style=filled]
# 		"team.table_22" [label=22 color=yellow style=filled]
# 		"team.table_27" [label=27 color=yellow style=filled]
# 		"team.table_30" [label=30 color=yellow style=filled]
# 		"team.table_47" [label=47 color=yellow style=filled]
# 		"team.table_51" [label=51 color=yellow style=filled]
# 		"team.table_53" [label=53 color=yellow style=filled]
# 		"team.table_55" [label=55 color=yellow style=filled]
# 	}
# 	subgraph group_7 {
# 		graph [rank=same_00000007]
# 		"team.table_7" [label=7 color=yellow style=filled]
# 		"team.table_17" [label=17 color=yellow style=filled]
# 		"team.table_19" [label=19 color=yellow style=filled]
# 		"team.table_33" [label=33 color=yellow style=filled]
# 		"team.table_36" [label=36 color=yellow style=filled]
# 	}
# 	subgraph group_8 {
# 		graph [rank=same_00000008]
# 		"team.table_14" [label=14 color=yellow style=filled]
# 		"team.table_20" [label=20 color=yellow style=filled]
# 		"team.table_35" [label=35 color=yellow style=filled]
# 		"team.table_38" [label=38 color=yellow style=filled]
# 	}
# 	subgraph group_9 {
# 		graph [rank=same_00000009]
# 		"team.table_21" [label=21 color=yellow style=filled]
# 		"team.table_48" [label=48 color=yellow style=filled]
# 	}
# 	subgraph group_10 {
# 		graph [rank=same_00000010]
# 		"team.table_56" [label=56 color=yellow style=filled]
# 		"team.table_57" [label=57 color=yellow style=filled]
# 	}
# }

# %%
dependency_graph(graph, reverse, rankings, 
                      fixed_size=True, 
                      scaler=4, 
                      with_node_constraints=True,
                      escalating_ranks=True
                     )

# %%
dependency_graph(graph, reverse, rankings, 
                      fixed_size=True, 
                      scaler=4, 
                      with_node_constraints=True,
                      escalating_ranks=False
                     )

# %%
dependency_graph(graph, reverse, rankings, True, fixed_size=True, scaler=0.5, escalating_ranks=True, top_to_bottom=False)

# %% [markdown]
# # Appendix 1: NetworkX - pretty nifty, but not quite right for drawing

# %%
color_map = [get_color(n) for n in G]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(14, 14)) 
nx.draw_networkx(G, with_label=True, node_color=color_map, pos=nx.kamada_kawai_layout(G))

# %%
plt.figure(figsize =(14, 14)) 
nx.draw_networkx(G, with_label=True, node_color=color_map, pos=nx.shell_layout(G, topo_ranks))

# %%
plt.figure(figsize =(14, 14)) 
nx.draw_networkx(G, with_label=True, node_color=color_map, pos=nx.shell_layout(G, shells))

# %%
plt.figure(figsize =(12, 12)) 
nx.draw_networkx(G, with_label=True, node_color=color_map, pos=nx.shell_layout(G))

# %%
plt.figure(figsize =(12, 12)) 
nx.draw_networkx(G, with_label=True, node_color=color_map, pos=nx.spring_layout(G))

# %%
plt.figure(figsize =(12, 12)) 
nx.draw_networkx(G, with_label=True, node_color=color_map, pos=nx.fruchterman_reingold_layout(G))

# %%
plt.figure(figsize =(14, 14)) 
nx.draw_networkx(G, with_label=True, node_color=color_map, pos=nx.spiral_layout(G))
